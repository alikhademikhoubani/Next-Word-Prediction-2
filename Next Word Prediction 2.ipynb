# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import gensim
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense
from keras.initializers import Constant

# %%
with open('Machine Learning.txt','r',encoding='utf-8') as myfile:
    mytext=myfile.read()

# %%
mytext[:1000]
# Out:
# "Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from data and generalize to unseen data, and thus perform tasks without explicit instructions.\nRecently, artificial neural networks have been able to surpass many previous approaches in performance.\nML finds application in many fields, including natural language processing, computer vision, speech recognition, email filtering, agriculture, and medicine.\nWhen applied to business problems, it is known under the name predictive analytics. Although not all machine learning is statistically based, computational statistics is an important source of the field's methods.\nThe mathematical foundations of ML are provided by mathematical optimization (mathematical programming) methods.\nData mining is a related (parallel) field of study, focusing on exploratory data analysis (EDA) through unsupervised learning.\nFrom a theoretical viewpoint, probably "

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts([mytext])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'a': 3,
#  'learning': 4,
#  'to': 5,
#  'and': 6,
#  'in': 7,
#  'is': 8,
#  'data': 9,
#  'machine': 10,
#  'that': 11,
#  'as': 12,
#  'by': 13,
#  'an': 14,
#  'for': 15,
#  'algorithms': 16,
#  'with': 17,
#  'are': 18,
#  'or': 19,
#  'from': 20,
#  'on': 21,
#  'model': 22,
#  'be': 23,
#  'training': 24,
#  'it': 25,
#  'can': 26,
#  'set': 27,
#  'based': 28,
#  'supervised': 29,
#  'methods': 30,
#  'unsupervised': 31,
#  'this': 32,
#  'has': 33,
#  'examples': 34,
#  'used': 35,
#  'algorithm': 36,
#  'compression': 37,
#  'feature': 38,
#  'such': 39,
#  'not': 40,
#  'also': 41,
#  'field': 42,
#  'other': 43,
#  'knowledge': 44,
#  'been': 45,
#  'which': 46,
#  'one': 47,
#  'input': 48,
#  'example': 49,
#  'many': 50,
#  'analysis': 51,
#  'was': 52,
#  'more': 53,
#  'its': 54,
#  'ai': 55,
#  'between': 56,
#  'rule': 57,
#  'have': 58,
#  'systems': 59,
#  'reinforcement': 60,
#  'into': 61,
#  'classification': 62,
#  'but': 63,
#  'detection': 64,
#  'artificial': 65,
#  'neural': 66,
#  'performance': 67,
#  'computer': 68,
#  'known': 69,
#  'mathematical': 70,
#  'programming': 71,
#  'mining': 72,
#  'each': 73,
#  'models': 74,
#  'some': 75,
#  'theory': 76,
#  'space': 77,
#  'image': 78,
#  'while': 79,
#  'techniques': 80,
#  'environment': 81,
#  'features': 82,
#  'dictionary': 83,
#  'statistical': 84,
#  'learn': 85,
#  'problems': 86,
#  'under': 87,
#  'statistics': 88,
#  'time': 89,
#  'using': 90,
#  'logic': 91,
#  'their': 92,
#  'goal': 93,
#  'system': 94,
#  'include': 95,
#  'represented': 96,
#  'often': 97,
#  'learned': 98,
#  'inputs': 99,
#  'intelligence': 100,
#  'research': 101,
#  'given': 102,
#  'do': 103,
#  'predictions': 104,
#  'representation': 105,
#  'function': 106,
#  'sparse': 107,
#  'rules': 108,
#  'study': 109,
#  'perform': 110,
#  'tasks': 111,
#  'without': 112,
#  'networks': 113,
#  'when': 114,
#  'all': 115,
#  'optimization': 116,
#  'related': 117,
#  'theoretical': 118,
#  'program': 119,
#  'human': 120,
#  'patterns': 121,
#  'e': 122,
#  'if': 123,
#  'two': 124,
#  'these': 125,
#  'were': 126,
#  'inductive': 127,
#  'output': 128,
#  'similarity': 129,
#  'both': 130,
#  'clustering': 131,
#  'clusters': 132,
#  'labels': 133,
#  'process': 134,
#  'reduction': 135,
#  'method': 136,
#  'generalization': 137,
#  'variables': 138,
#  'outputs': 139,
#  'labeled': 140,
#  'dimensional': 141,
#  'approaches': 142,
#  'including': 143,
#  'processing': 144,
#  'computational': 145,
#  'self': 146,
#  'called': 147,
#  'had': 148,
#  'so': 149,
#  'class': 150,
#  'make': 151,
#  'may': 152,
#  'they': 153,
#  'then': 154,
#  'within': 155,
#  'information': 156,
#  'same': 157,
#  'vector': 158,
#  'instead': 159,
#  'software': 160,
#  'k': 161,
#  'means': 162,
#  'large': 163,
#  'discovery': 164,
#  'will': 165,
#  'only': 166,
#  'new': 167,
#  'about': 168,
#  'complexity': 169,
#  'no': 170,
#  'any': 171,
#  'dimensionality': 172,
#  'cluster': 173,
#  'component': 174,
#  'anomaly': 175,
#  'association': 176,
#  'ml': 177,
#  'concerned': 178,
#  'unseen': 179,
#  'language': 180,
#  'applied': 181,
#  'provided': 182,
#  'term': 183,
#  'introduced': 184,
#  'history': 185,
#  'behavior': 186,
#  'certain': 187,
#  'researchers': 188,
#  'developed': 189,
#  'representative': 190,
#  'machines': 191,
#  'pattern': 192,
#  'network': 193,
#  'learns': 194,
#  'definition': 195,
#  'experience': 196,
#  'than': 197,
#  'use': 198,
#  'order': 199,
#  'problem': 200,
#  'there': 201,
#  'distribution': 202,
#  'best': 203,
#  'general': 204,
#  'x': 205,
#  'underlying': 206,
#  'three': 207,
#  'audio': 208,
#  'points': 209,
#  'unknown': 210,
#  'different': 211,
#  'task': 212,
#  'loss': 213,
#  'instances': 214,
#  'pre': 215,
#  'deep': 216,
#  'principal': 217,
#  'g': 218,
#  'area': 219,
#  'context': 220,
#  'hypothesis': 221,
#  'results': 222,
#  'discovering': 223,
#  'matrix': 224,
#  'identify': 225,
#  'observations': 226,
#  'genetic': 227,
#  'typically': 228,
#  'either': 229,
#  'manifold': 230,
#  'caa': 231,
#  'representations': 232,
#  'outlier': 233,
#  'normal': 234,
#  'previous': 235,
#  'finds': 236,
#  'fields': 237,
#  'recognition': 238,
#  'email': 239,
#  'although': 240,
#  'through': 241,
#  'approximately': 242,
#  'cognitive': 243,
#  'book': 244,
#  'structure': 245,
#  'how': 246,
#  'work': 247,
#  'well': 248,
#  'early': 249,
#  'come': 250,
#  'trained': 251,
#  'teacher': 252,
#  'decisions': 253,
#  '4': 254,
#  'respect': 255,
#  'rather': 256,
#  'terms': 257,
#  'future': 258,
#  'specific': 259,
#  'approach': 260,
#  'various': 261,
#  'symbolic': 262,
#  'found': 263,
#  'probabilistic': 264,
#  'employed': 265,
#  'medical': 266,
#  'however': 267,
#  'logical': 268,
#  'leading': 269,
#  'ilp': 270,
#  'science': 271,
#  'nature': 272,
#  'optimal': 273,
#  'prediction': 274,
#  'show': 275,
#  'vectors': 276,
#  'associated': 277,
#  'lossless': 278,
#  'according': 279,
#  'smaller': 280,
#  'similar': 281,
#  'number': 282,
#  'signal': 283,
#  'original': 284,
#  'significantly': 285,
#  'previously': 286,
#  'step': 287,
#  'databases': 288,
#  'learner': 289,
#  'accuracy': 290,
#  'separate': 291,
#  'being': 292,
#  'evaluated': 293,
#  'key': 294,
#  'cannot': 295,
#  'functions': 296,
#  'difference': 297,
#  'require': 298,
#  'addition': 299,
#  'contrast': 300,
#  'built': 301,
#  'applications': 302,
#  'considered': 303,
#  'sets': 304,
#  'does': 305,
#  'polynomial': 306,
#  'positive': 307,
#  'negative': 308,
#  'feedback': 309,
#  'desired': 310,
#  'game': 311,
#  'allows': 312,
#  'regression': 313,
#  'would': 314,
#  'objects': 315,
#  'unlabeled': 316,
#  'higher': 317,
#  'low': 318,
#  'situations': 319,
#  'where': 320,
#  'attempt': 321,
#  'rare': 322,
#  'items': 323,
#  'test': 324,
#  'classifier': 325,
#  'generalize': 326,
#  'thus': 327,
#  'explicit': 328,
#  'able': 329,
#  'application': 330,
#  'natural': 331,
#  'vision': 332,
#  'speech': 333,
#  'name': 334,
#  'predictive': 335,
#  'probably': 336,
#  'correct': 337,
#  'pac': 338,
#  'arthur': 339,
#  'samuel': 340,
#  'teaching': 341,
#  'computers': 342,
#  'processes': 343,
#  'he': 344,
#  'formed': 345,
#  'neurons': 346,
#  'who': 347,
#  'studied': 348,
#  'modern': 349,
#  'up': 350,
#  '1960s': 351,
#  'memory': 352,
#  'analyze': 353,
#  'recognize': 354,
#  'during': 355,
#  'mostly': 356,
#  'interest': 357,
#  'continued': 358,
#  '1981': 359,
#  'said': 360,
#  't': 361,
#  'measure': 362,
#  'p': 363,
#  'at': 364,
#  'improves': 365,
#  'defining': 366,
#  'question': 367,
#  'what': 368,
#  'we': 369,
#  'classify': 370,
#  'moles': 371,
#  'train': 372,
#  'out': 373,
#  'having': 374,
#  'perceptrons': 375,
#  'linear': 376,
#  'especially': 377,
#  'practical': 378,
#  'line': 379,
#  'outside': 380,
#  'too': 381,
#  'disciplines': 382,
#  'own': 383,
#  'toward': 384,
#  'probability': 385,
#  'connection': 386,
#  'sequence': 387,
#  'coding': 388,
#  'compressor': 389,
#  'finding': 390,
#  'alternative': 391,
#  'measures': 392,
#  'spaces': 393,
#  'c': 394,
#  'define': 395,
#  'maps': 396,
#  'corresponding': 397,
#  'examination': 398,
#  'directly': 399,
#  'possible': 400,
#  'zip': 401,
#  'compressed': 402,
#  'size': 403,
#  'file': 404,
#  'combined': 405,
#  'powered': 406,
#  'video': 407,
#  'high': 408,
#  'technique': 409,
#  'extensive': 410,
#  'datasets': 411,
#  'storage': 412,
#  'particularly': 413,
#  'core': 414,
#  'capable': 415,
#  'chinchilla': 416,
#  '70b': 417,
#  'conventional': 418,
#  'images': 419,
#  'focuses': 420,
#  'properties': 421,
#  'assumptions': 422,
#  'usually': 423,
#  'ability': 424,
#  'kdd': 425,
#  'due': 426,
#  'correctly': 427,
#  'predict': 428,
#  'active': 429,
#  'topic': 430,
#  'closely': 431,
#  'call': 432,
#  'most': 433,
#  'accurate': 434,
#  'modeling': 435,
#  'paradigms': 436,
#  'algorithmic': 437,
#  'less': 438,
#  'random': 439,
#  'physics': 440,
#  'scale': 441,
#  'objective': 442,
#  'after': 443,
#  'build': 444,
#  'produce': 445,
#  'bounds': 446,
#  'common': 447,
#  'way': 448,
#  'error': 449,
#  'complex': 450,
#  'broad': 451,
#  'categories': 452,
#  'find': 453,
#  'dynamic': 454,
#  'against': 455,
#  'opponent': 456,
#  'rewards': 457,
#  'maximize': 458,
#  'contains': 459,
#  'array': 460,
#  'sometimes': 461,
#  'determine': 462,
#  'limited': 463,
#  'value': 464,
#  'verification': 465,
#  'commonalities': 466,
#  'density': 467,
#  'genome': 468,
#  'defined': 469,
#  'members': 470,
#  'semi': 471,
#  'actions': 472,
#  'mdp': 473,
#  'exact': 474,
#  'reducing': 475,
#  'dimension': 476,
#  'popular': 477,
#  'pca': 478,
#  'involves': 479,
#  'changing': 480,
#  '3d': 481,
#  '2d': 482,
#  'along': 483,
#  'assumption': 484,
#  'fit': 485,
#  'meta': 486,
#  'crossbar': 487,
#  'external': 488,
#  'advice': 489,
#  'emotions': 490,
#  'consequence': 491,
#  'emotion': 492,
#  'situation': 493,
#  'behavioral': 494,
#  'initial': 495,
#  'several': 496,
#  'aim': 497,
#  'useful': 498,
#  'performing': 499,
#  'generating': 500,
#  'them': 501,
#  'constraint': 502,
#  'discover': 503,
#  'level': 504,
#  'explain': 505,
#  'observed': 506,
#  'basis': 507,
#  'sparsely': 508,
#  'noise': 509,
#  'identification': 510,
#  'majority': 511,
#  'represent': 512,
#  'anomalies': 513,
#  'particular': 514,
#  'intrusion': 515,
#  'detect': 516,
#  'representing': 517,
#  'instance': 518,
#  'strong': 519,
#  'store': 520,
#  'apply': 521,
#  'collectively': 522,
#  'transaction': 523,
#  'bioinformatics': 524,
#  'background': 525,
#  'hypotheses': 526,
#  'facts': 527,
#  'programs': 528,
#  'shapiro': 529,
#  'induction': 530,
#  'development': 531,
#  'instructions': 532,
#  'recently': 533,
#  'surpass': 534,
#  'filtering': 535,
#  'agriculture': 536,
#  'medicine': 537,
#  'business': 538,
#  'analytics': 539,
#  'statistically': 540,
#  'important': 541,
#  'source': 542,
#  "field's": 543,
#  'foundations': 544,
#  'parallel': 545,
#  'focusing': 546,
#  'exploratory': 547,
#  'eda': 548,
#  'viewpoint': 549,
#  'provides': 550,
#  'framework': 551,
#  'describing': 552,
#  'coined': 553,
#  '1959': 554,
#  'ibm': 555,
#  'employee': 556,
#  'pioneer': 557,
#  'gaming': 558,
#  'synonym': 559,
#  'period': 560,
#  'earliest': 561,
#  '1950s': 562,
#  'invented': 563,
#  'calculated': 564,
#  'winning': 565,
#  'chance': 566,
#  'checkers': 567,
#  'side': 568,
#  'roots': 569,
#  'back': 570,
#  'decades': 571,
#  'desire': 572,
#  'effort': 573,
#  '1949': 574,
#  'canadian': 575,
#  'psychologist': 576,
#  'donald': 577,
#  'hebb': 578,
#  'published': 579,
#  'organization': 580,
#  'interactions': 581,
#  'among': 582,
#  'nerve': 583,
#  'cells': 584,
#  "hebb's": 585,
#  'interacting': 586,
#  'another': 587,
#  'groundwork': 588,
#  'ais': 589,
#  'nodes': 590,
#  'communicate': 591,
#  'contributed': 592,
#  'technologies': 593,
#  'logician': 594,
#  'walter': 595,
#  'pitts': 596,
#  'warren': 597,
#  'mcculloch': 598,
#  'proposed': 599,
#  'mirror': 600,
#  'thought': 601,
#  'experimental': 602,
#  'punched': 603,
#  'tape': 604,
#  'cybertron': 605,
#  'raytheon': 606,
#  'company': 607,
#  'sonar': 608,
#  'signals': 609,
#  'electrocardiograms': 610,
#  'rudimentary': 611,
#  'repetitively': 612,
#  'operator': 613,
#  'equipped': 614,
#  'goof': 615,
#  'button': 616,
#  'cause': 617,
#  're': 618,
#  'evaluate': 619,
#  'incorrect': 620,
#  "nilsson's": 621,
#  'dealing': 622,
#  '1970s': 623,
#  'described': 624,
#  'duda': 625,
#  'hart': 626,
#  '1973': 627,
#  'report': 628,
#  'strategies': 629,
#  '40': 630,
#  'characters': 631,
#  '26': 632,
#  'letters': 633,
#  '10': 634,
#  'digits': 635,
#  'special': 636,
#  'symbols': 637,
#  'terminal': 638,
#  'tom': 639,
#  'm': 640,
#  'mitchell': 641,
#  'widely': 642,
#  'quoted': 643,
#  'formal': 644,
#  'studiedin': 645,
#  'measured': 646,
#  'offers': 647,
#  'fundamentally': 648,
#  'operational': 649,
#  'follows': 650,
#  'alan': 651,
#  "turing's": 652,
#  'proposal': 653,
#  'his': 654,
#  'paper': 655,
#  'computing': 656,
#  'machinery': 657,
#  'think': 658,
#  'replaced': 659,
#  'thinking': 660,
#  'entities': 661,
#  'day': 662,
#  'objectives': 663,
#  'purpose': 664,
#  'outcomes': 665,
#  'hypothetical': 666,
#  'classifying': 667,
#  'coupled': 668,
#  'cancerous': 669,
#  'stock': 670,
#  'trading': 671,
#  'inform': 672,
#  'trader': 673,
#  'potential': 674,
#  'scientific': 675,
#  'endeavor': 676,
#  'grew': 677,
#  'quest': 678,
#  'days': 679,
#  'academic': 680,
#  'discipline': 681,
#  'interested': 682,
#  'attempted': 683,
#  'termed': 684,
#  'later': 685,
#  'reinventions': 686,
#  'generalized': 687,
#  'reasoning': 688,
#  'automated': 689,
#  'diagnosis': 690,
#  'increasing': 691,
#  'emphasis': 692,
#  'caused': 693,
#  'rift': 694,
#  'plagued': 695,
#  'acquisition': 696,
#  '1980': 697,
#  'expert': 698,
#  'dominate': 699,
#  'favor': 700,
#  'did': 701,
#  'continue': 702,
#  'now': 703,
#  'proper': 704,
#  'retrieval': 705,
#  'abandoned': 706,
#  'around': 707,
#  'cs': 708,
#  'connectionism': 709,
#  'hopfield': 710,
#  'rumelhart': 711,
#  'hinton': 712,
#  'main': 713,
#  'success': 714,
#  'came': 715,
#  'mid': 716,
#  '1980s': 717,
#  'reinvention': 718,
#  'backpropagation': 719,
#  'reorganized': 720,
#  'recognized': 721,
#  'started': 722,
#  'flourish': 723,
#  '1990s': 724,
#  'changed': 725,
#  'achieving': 726,
#  'tackling': 727,
#  'solvable': 728,
#  'shifted': 729,
#  'focus': 730,
#  'away': 731,
#  'inherited': 732,
#  'borrowed': 733,
#  'fuzzy': 734,
#  'close': 735,
#  'predicts': 736,
#  'posterior': 737,
#  'probabilities': 738,
#  'entire': 739,
#  'arithmetic': 740,
#  'conversely': 741,
#  'symbol': 742,
#  'compresses': 743,
#  'equivalence': 744,
#  'justification': 745,
#  'benchmark': 746,
#  'view': 747,
#  'implicitly': 748,
#  'map': 749,
#  'strings': 750,
#  'implicit': 751,
#  'compute': 752,
#  'ℵ': 753,
#  'string': 754,
#  'norm': 755,
#  'exhaustive': 756,
#  'precluded': 757,
#  'chooses': 758,
#  'examine': 759,
#  'lzw': 760,
#  'lz77': 761,
#  'ppm': 762,
#  'aixi': 763,
#  'explained': 764,
#  'hutter': 765,
#  'prize': 766,
#  'smallest': 767,
#  'generates': 768,
#  "file's": 769,
#  'includes': 770,
#  'unzipping': 771,
#  'since': 772,
#  'you': 773,
#  'unzip': 774,
#  'even': 775,
#  'form': 776,
#  'vp9': 777,
#  'nvidia': 778,
#  'maxine': 779,
#  'aivc': 780,
#  'accmpeg': 781,
#  'opencv': 782,
#  'tensorflow': 783,
#  "matlab's": 784,
#  'toolbox': 785,
#  'ipt': 786,
#  'fidelity': 787,
#  'generative': 788,
#  'utilized': 789,
#  'compress': 790,
#  'grouping': 791,
#  'simplifies': 792,
#  'handling': 793,
#  'lack': 794,
#  'predefined': 795,
#  'widespread': 796,
#  'aims': 797,
#  'reduce': 798,
#  'files': 799,
#  'enhancing': 800,
#  'efficiency': 801,
#  'speeding': 802,
#  'transmission': 803,
#  'partition': 804,
#  'dataset': 805,
#  'specified': 806,
#  'centroid': 807,
#  'condenses': 808,
#  'compact': 809,
#  'beneficial': 810,
#  'aids': 811,
#  'replacing': 812,
#  'groups': 813,
#  'centroids': 814,
#  'thereby': 815,
#  'preserving': 816,
#  'decreasing': 817,
#  'required': 818,
#  'demonstrated': 819,
#  "deepmind's": 820,
#  'deepmind': 821,
#  'effectively': 822,
#  'outperforming': 823,
#  'portable': 824,
#  'graphics': 825,
#  'png': 826,
#  'free': 827,
#  'codec': 828,
#  'flac': 829,
#  'achieved': 830,
#  '43': 831,
#  '16': 832,
#  'sizes': 833,
#  'respectively': 834,
#  'employ': 835,
#  'overlap': 836,
#  'uses': 837,
#  'goals': 838,
#  'hand': 839,
#  'employs': 840,
#  'preprocessing': 841,
#  'improve': 842,
#  'much': 843,
#  'confusion': 844,
#  'communities': 845,
#  'conferences': 846,
#  'journals': 847,
#  'ecml': 848,
#  'pkdd': 849,
#  'major': 850,
#  'exception': 851,
#  'comes': 852,
#  'basic': 853,
#  'reproduce': 854,
#  'uninformed': 855,
#  'easily': 856,
#  'outperformed': 857,
#  'typical': 858,
#  'unavailability': 859,
#  'intimate': 860,
#  'ties': 861,
#  'formulated': 862,
#  'minimization': 863,
#  'express': 864,
#  'discrepancy': 865,
#  'actual': 866,
#  'wants': 867,
#  'assign': 868,
#  'label': 869,
#  'assigned': 870,
#  'arises': 871,
#  'minimize': 872,
#  'minimizing': 873,
#  'samples': 874,
#  'characterizing': 875,
#  'current': 876,
#  'distinct': 877,
#  'draws': 878,
#  'population': 879,
#  'inferences': 880,
#  'sample': 881,
#  'generalizable': 882,
#  '36': 883,
#  'michael': 884,
#  'i': 885,
#  'jordan': 886,
#  'ideas': 887,
#  'methodological': 888,
#  'principles': 889,
#  'tools': 890,
#  'long': 891,
#  'suggested': 892,
#  'placeholder': 893,
#  'overall': 894,
#  'analyses': 895,
#  'priori': 896,
#  'selection': 897,
#  'suitable': 898,
#  'significant': 899,
#  'theoretically': 900,
#  'relevant': 901,
#  'included': 902,
#  'structured': 903,
#  'shape': 904,
#  'detecting': 905,
#  'ultimate': 906,
#  'leo': 907,
#  'breiman': 908,
#  'distinguished': 909,
#  'wherein': 910,
#  'like': 911,
#  'forest': 912,
#  'statisticians': 913,
#  'adopted': 914,
#  'analytical': 915,
#  'derived': 916,
#  'rooted': 917,
#  'disordered': 918,
#  'extended': 919,
#  'weight': 920,
#  'diagnostics': 921,
#  'accurately': 922,
#  'experienced': 923,
#  'generally': 924,
#  'occurrences': 925,
#  'enables': 926,
#  'sufficiently': 927,
#  'cases': 928,
#  'branch': 929,
#  'via': 930,
#  'because': 931,
#  'finite': 932,
#  'uncertain': 933,
#  'yield': 934,
#  'guarantees': 935,
#  'quite': 936,
#  'bias–variance': 937,
#  'decomposition': 938,
#  'quantify': 939,
#  'should': 940,
#  'match': 941,
#  'fitted': 942,
#  'increased': 943,
#  'response': 944,
#  'decreases': 945,
#  'subject': 946,
#  'overfitting': 947,
#  'poorer': 948,
#  'theorists': 949,
#  'feasibility': 950,
#  'computation': 951,
#  'feasible': 952,
#  'done': 953,
#  'kinds': 954,
#  'classes': 955,
#  'traditionally': 956,
#  'divided': 957,
#  'correspond': 958,
#  'depending': 959,
#  'available': 960,
#  'presented': 961,
#  'leaving': 962,
#  'itself': 963,
#  'hidden': 964,
#  'towards': 965,
#  'end': 966,
#  'interacts': 967,
#  'must': 968,
#  'driving': 969,
#  'vehicle': 970,
#  'playing': 971,
#  'navigates': 972,
#  "that's": 973,
#  'analogous': 974,
#  'tries': 975,
#  'advantages': 976,
#  'limitations': 977,
#  'single': 978,
#  'works': 979,
#  'consists': 980,
#  'supervisory': 981,
#  'iterative': 982,
#  'part': 983,
#  'over': 984,
#  'types': 985,
#  'restricted': 986,
#  'values': 987,
#  'numerical': 988,
#  'range': 989,
#  'filters': 990,
#  'emails': 991,
#  'incoming': 992,
#  'folder': 993,
#  'ranking': 994,
#  'recommendation': 995,
#  'visual': 996,
#  'identity': 997,
#  'tracking': 998,
#  'face': 999,
#  'speaker': 1000,
#  ...}

# %%
all_sequences=[]
for line in mytext.split('\n'):
    sequence=tokenizer.texts_to_sequences([line])[0]
    all_sequences.append(sequence)

# %%
all_sequences[1]
# Out:
# [533, 65, 66, 113, 58, 45, 329, 5, 534, 50, 235, 142, 7, 67]

# %%
all_seq=[]
for seq in all_sequences:
    for i in range(1,len(seq)):
        se=seq[:i+1]
        all_seq.append(se)

# %%
all_seq[:10]
# Out:
# [[10, 4],
#  [10, 4, 177],
#  [10, 4, 177, 8],
#  [10, 4, 177, 8, 3],
#  [10, 4, 177, 8, 3, 42],
#  [10, 4, 177, 8, 3, 42, 2],
#  [10, 4, 177, 8, 3, 42, 2, 109],
#  [10, 4, 177, 8, 3, 42, 2, 109, 7],
#  [10, 4, 177, 8, 3, 42, 2, 109, 7, 65],
#  [10, 4, 177, 8, 3, 42, 2, 109, 7, 65, 100]]

# %%
maxlen=max([len(i) for i in all_seq])
pad_seq=np.array(pad_sequences(all_seq,maxlen=maxlen,padding='pre'))

# %%
pad_seq
# Out:
# array([[   0,    0,    0, ...,    0,   10,    4],
#        [   0,    0,    0, ...,   10,    4,  177],
#        [   0,    0,    0, ...,    4,  177,    8],
#        ...,
#        [   0,    0,    0, ...,    2,    3,  248],
#        [   0,    0,    0, ...,    3,  248, 1319],
#        [   0,    0,    0, ...,  248, 1319,   27]])

# %%
X=pad_seq[:,:-1]
y=pad_seq[:,-1]

# %%
X
# Out:
# array([[   0,    0,    0, ...,    0,    0,   10],
#        [   0,    0,    0, ...,    0,   10,    4],
#        [   0,    0,    0, ...,   10,    4,  177],
#        ...,
#        [   0,    0,    0, ...,  470,    2,    3],
#        [   0,    0,    0, ...,    2,    3,  248],
#        [   0,    0,    0, ...,    3,  248, 1319]])

# %%
y
# Out:
# array([   4,  177,    8, ...,  248, 1319,   27])

# %%
len(X)
# Out:
# 4499

# %%
len(y)
# Out:
# 4499

# %%
embedding_dictionary=dict()
glove_file=open('glove.6B.100d.txt',encoding='utf8')
for line in glove_file:
    records=line.split()
    word=records[0]
    vector_dimensions=np.array(records[1:],dtype='float32')
    embedding_dictionary[word]=vector_dimensions
glove_file.close()

# %%
embedding_dictionary['the']
# Out:
# array([-0.038194, -0.24487 ,  0.72812 , -0.39961 ,  0.083172,  0.043953,
#        -0.39141 ,  0.3344  , -0.57545 ,  0.087459,  0.28787 , -0.06731 ,
#         0.30906 , -0.26384 , -0.13231 , -0.20757 ,  0.33395 , -0.33848 ,
#        -0.31743 , -0.48336 ,  0.1464  , -0.37304 ,  0.34577 ,  0.052041,
#         0.44946 , -0.46971 ,  0.02628 , -0.54155 , -0.15518 , -0.14107 ,
#        -0.039722,  0.28277 ,  0.14393 ,  0.23464 , -0.31021 ,  0.086173,
#         0.20397 ,  0.52624 ,  0.17164 , -0.082378, -0.71787 , -0.41531 ,
#         0.20335 , -0.12763 ,  0.41367 ,  0.55187 ,  0.57908 , -0.33477 ,
#        -0.36559 , -0.54857 , -0.062892,  0.26584 ,  0.30205 ,  0.99775 ,
#        -0.80481 , -3.0243  ,  0.01254 , -0.36942 ,  2.2167  ,  0.72201 ,
#        -0.24978 ,  0.92136 ,  0.034514,  0.46745 ,  1.1079  , -0.19358 ,
#        -0.074575,  0.23353 , -0.052062, -0.22044 ,  0.057162, -0.15806 ,
#        -0.30798 , -0.41625 ,  0.37972 ,  0.15006 , -0.53212 , -0.2055  ,
#        -1.2526  ,  0.071624,  0.70565 ,  0.49744 , -0.42063 ,  0.26148 ,
#        -1.538   , -0.30223 , -0.073438, -0.28312 ,  0.37104 , -0.25217 ,
#         0.016215, -0.017099, -0.38984 ,  0.87424 , -0.72569 , -0.51058 ,
#        -0.52028 , -0.1459  ,  0.8278  ,  0.27062 ], dtype=float32)

# %%
embedding_matrix=np.zeros((vocab_size,DIM))
for word,index in tokenizer.word_index.items():
    embedding_vector=embedding_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index]=embedding_vector

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.038194  , -0.24487001,  0.72812003, ..., -0.1459    ,
#          0.82779998,  0.27061999],
#        [-0.1529    , -0.24279   ,  0.89837003, ..., -0.59100002,
#          1.00390005,  0.20664001],
#        ...,
#        [-0.09901   , -0.28292999,  0.59741998, ..., -0.20057   ,
#          0.011939  ,  0.61221999],
#        [ 0.76877999, -0.33102   , -0.0075087 , ..., -0.34268001,
#          0.66249001, -0.92395997],
#        [ 0.080861  , -0.85575002, -0.69593   , ..., -0.056623  ,
#         -0.21822999, -0.44773999]])

# %%
model=Sequential()

# %%
model.add(Embedding(vocab_size,DIM,embeddings_initializer=Constant(embedding_matrix),trainable=False,input_shape=(maxlen,)))
model.add(LSTM(150))
model.add(Dense(vocab_size,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 100, 100)            │         132,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 150)                 │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1320)                │         199,320 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 481,920 (1.84 MB)
#  Trainable params: 481,920 (1.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(X,y,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 19s 88ms/step - accuracy: 0.0398 - loss: 6.6431
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.0661 - loss: 5.9995
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.0876 - loss: 5.7499
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.1171 - loss: 5.3899
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.1322 - loss: 5.1173
# Epoch 6/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.1590 - loss: 4.7604
# Epoch 7/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.1852 - loss: 4.4876
# Epoch 8/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.2043 - loss: 4.1339
# Epoch 9/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.2452 - loss: 3.7697
# Epoch 10/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - accuracy: 0.2901 - loss: 3.4530
# Epoch 11/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.3373 - loss: 3.2188
# Epoch 12/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.4055 - loss: 2.9062
# Epoch 13/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.4606 - loss: 2.6366
# Epoch 14/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.5305 - loss: 2.3557
# Epoch 15/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.5910 - loss: 2.1426
# Epoch 16/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6461 - loss: 1.9166
# Epoch 17/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.6920 - loss: 1.7235
# Epoch 18/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.7447 - loss: 1.5320
# Epoch 19/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.7780 - loss: 1.3837
# Epoch 20/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.8112 - loss: 1.2149
# Epoch 21/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 25s 140ms/step - accuracy: 0.8455 - loss: 1.0569
# Epoch 22/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - accuracy: 0.8645 - loss: 0.9492
# Epoch 23/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.8827 - loss: 0.8543
# Epoch 24/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 105ms/step - accuracy: 0.8948 - loss: 0.7616
# Epoch 25/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9112 - loss: 0.6873
# Epoch 26/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.9251 - loss: 0.6151
# Epoch 27/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9292 - loss: 0.5587
# Epoch 28/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9451 - loss: 0.4824
# Epoch 29/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9459 - loss: 0.4332
# Epoch 30/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9577 - loss: 0.3982
# Epoch 31/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9583 - loss: 0.3575
# Epoch 32/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9607 - loss: 0.3211
# Epoch 33/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.9616 - loss: 0.2933
# Epoch 34/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9702 - loss: 0.2625
# Epoch 35/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9671 - loss: 0.2467
# Epoch 36/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9647 - loss: 0.2326
# Epoch 37/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9708 - loss: 0.2092
# Epoch 38/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9734 - loss: 0.1931
# Epoch 39/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9679 - loss: 0.1893
# Epoch 40/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9727 - loss: 0.1688
# Epoch 41/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9776 - loss: 0.1543
# Epoch 42/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9717 - loss: 0.1434
# Epoch 43/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.9698 - loss: 0.1423
# Epoch 44/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9727 - loss: 0.1354
# Epoch 45/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9710 - loss: 0.1281
# Epoch 46/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9700 - loss: 0.1204
# Epoch 47/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.9725 - loss: 0.1174
# Epoch 48/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.9707 - loss: 0.1193
# Epoch 49/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9754 - loss: 0.0996
# Epoch 50/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.9712 - loss: 0.1086

# %%
def next_word(input_text,predict_next_words):
    for _ in range(predict_next_words):
        input_seq=tokenizer.texts_to_sequences([input_text])[0]
        input_pad=np.array(pad_sequences([input_seq],maxlen=maxlen-1,padding='pre'))
        predict=np.argmax(model.predict(input_pad),axis=-1)
        output_text=''
        for word,index in tokenizer.word_index.items():
            if predict==index:
                output_text=word
                break
        input_text=input_text+' '+output_text
    return input_text

# %%
next_word('Machine learning is',10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 'Machine learning is a general term for any machine learning method that identifies'

# %%
next_word('used in this',5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 'used in this context is to classify data'

# %%
next_word('supervised learning is',10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 'supervised learning is a rule based machine learning method for discovering relationships between'

# %%
next_word('unsupervised learning',10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 'unsupervised learning algorithms find structures in data that has not been labeled'

# %%
next_word('A popular heuristic method',10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 'A popular heuristic method for sparse dictionary learning is the k svd algorithm is'

# %%
next_word('A popular heuristic way',10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 'A popular heuristic way that can be used in a way that makes it'
